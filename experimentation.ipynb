# %%
# Librairies
import pandas as pd
import numpy as np

# %%
# Data of investors/individuals
investors = pd.read_csv('data/InputData.csv', index_col = 0)
print(investors.shape)
investors.head()
# Out:
# (4810, 12)
#    AGE07  EDCL07  MARRIED07  KIDS07  LIFECL07  OCCAT107      INCOME07  RISK07  \
# 0     47       2          1       0         2         1  56443.744181       3
# 1     47       2          1       0         2         1  56443.744181       3
# 2     47       2          1       0         2         1  56443.744181       3
# 3     47       2          1       0         2         1  56443.744181       3
# 4     47       2          1       0         2         1  56443.744181       3
#
#    WSAVED07  SPENDMOR07    NETWORTH07  TrueRiskTol
# 0         1           5  352641.71130     6.947439
# 1         1           5  340525.21881     6.223158
# 2         1           5  348696.08426     6.676709
# 3         1           5  351802.87720     6.286854
# 4         1           5  358958.85696     6.177016

# %%
# Market data (all stocks in sp&500)
assets = pd.read_csv('data/SP500Data.csv',index_col=0)
print(assets.shape)
assets.head()
# Out:
# (448, 502)
#                   ABT        ABBV        ABMD         ACN       ATVI  \
# Date
# 2018-01-02  58.790001   98.410004  192.490005  153.839996  64.309998
# 2018-01-03  58.919998   99.949997  195.820007  154.550003  65.309998
# 2018-01-04  58.820000   99.379997  199.250000  156.380005  64.660004
# 2018-01-05  58.990002  101.110001  202.320007  157.669998  66.370003
# 2018-01-08  58.820000   99.489998  207.800003  158.929993  66.629997
#
#                   ADBE    AMD         AAP    AES         AMG  ...        WLTW  \
# Date                                                          ...
# 2018-01-02  177.699997  10.98  106.089996  10.88  203.039993  ...  146.990005
# 2018-01-03  181.039993  11.55  107.050003  10.87  202.119995  ...  149.740005
# 2018-01-04  183.220001  12.12  111.000000  10.83  198.539993  ...  151.259995
# 2018-01-05  185.339996  11.88  112.180000  10.87  199.470001  ...  152.229996
# 2018-01-08  185.039993  12.28  111.389999  10.87  200.529999  ...  151.410004
#
#                   WYNN        XEL        XRX       XLNX        XYL        YUM  \
# Date
# 2018-01-02  164.300003  47.810001  29.370001  67.879997  68.070000  81.599998
# 2018-01-03  162.520004  47.490002  29.330000  69.239998  68.900002  81.529999
# 2018-01-04  163.399994  47.119999  29.690001  70.489998  69.360001  82.360001
# 2018-01-05  164.490005  46.790001  29.910000  74.150002  69.230003  82.839996
# 2018-01-08  162.300003  47.139999  30.260000  74.639999  69.480003  82.980003
#
#                    ZBH       ZION        ZTS
# Date
# 2018-01-02  124.059998  50.700001  71.769997
# 2018-01-03  124.919998  50.639999  72.099998
# 2018-01-04  124.739998  50.849998  72.529999
# 2018-01-05  125.980003  50.869999  73.360001
# 2018-01-08  126.220001  50.619999  74.239998
#
# [5 rows x 502 columns]

# %% [markdown]
# Let's clean the market data.

# %%
missing_fractions = assets.isnull().mean().sort_values(ascending=False)
missing_fractions.head(10)
# Out:
# CTVA    0.781250
# DOW     0.678571
# FOX     0.667411
# FOXA    0.665179
# NOV     0.000000
# MSI     0.000000
# MSCI    0.000000
# MYL     0.000000
# NDAQ    0.000000
# ABT     0.000000
# dtype: float64

# %%
drop_list = sorted(list(missing_fractions[missing_fractions > 0.3].index))
drop_list
# Out:
# ['CTVA', 'DOW', 'FOX', 'FOXA']

# %%
assets.drop(labels=drop_list, axis=1, inplace=True)
assets.shape
# Out:
# (448, 498)

# %%
# Fill the missing values with the last value available in the dataset. 
assets=assets.fillna(method='ffill')
assets.head()
# Out:
#                   ABT        ABBV        ABMD         ACN       ATVI  \
# Date
# 2018-01-02  58.790001   98.410004  192.490005  153.839996  64.309998
# 2018-01-03  58.919998   99.949997  195.820007  154.550003  65.309998
# 2018-01-04  58.820000   99.379997  199.250000  156.380005  64.660004
# 2018-01-05  58.990002  101.110001  202.320007  157.669998  66.370003
# 2018-01-08  58.820000   99.489998  207.800003  158.929993  66.629997
#
#                   ADBE    AMD         AAP    AES         AMG  ...        WLTW  \
# Date                                                          ...
# 2018-01-02  177.699997  10.98  106.089996  10.88  203.039993  ...  146.990005
# 2018-01-03  181.039993  11.55  107.050003  10.87  202.119995  ...  149.740005
# 2018-01-04  183.220001  12.12  111.000000  10.83  198.539993  ...  151.259995
# 2018-01-05  185.339996  11.88  112.180000  10.87  199.470001  ...  152.229996
# 2018-01-08  185.039993  12.28  111.389999  10.87  200.529999  ...  151.410004
#
#                   WYNN        XEL        XRX       XLNX        XYL        YUM  \
# Date
# 2018-01-02  164.300003  47.810001  29.370001  67.879997  68.070000  81.599998
# 2018-01-03  162.520004  47.490002  29.330000  69.239998  68.900002  81.529999
# 2018-01-04  163.399994  47.119999  29.690001  70.489998  69.360001  82.360001
# 2018-01-05  164.490005  46.790001  29.910000  74.150002  69.230003  82.839996
# 2018-01-08  162.300003  47.139999  30.260000  74.639999  69.480003  82.980003
#
#                    ZBH       ZION        ZTS
# Date
# 2018-01-02  124.059998  50.700001  71.769997
# 2018-01-03  124.919998  50.639999  72.099998
# 2018-01-04  124.739998  50.849998  72.529999
# 2018-01-05  125.980003  50.869999  73.360001
# 2018-01-08  126.220001  50.619999  74.239998
#
# [5 rows x 498 columns]

# %% [markdown]
# ## Regression model for predicting risk tolerance

# %%
# load dataset
dataset = pd.read_excel('data/SCFP2009panel.xlsx')
print(dataset.shape)
dataset.head()

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.3.0
